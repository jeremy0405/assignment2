# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremy0405/assignment2/blob/main/ResNet18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms

# %%
if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

# %%
    test_set = torchvision.datasets.ImageFolder(root="/content/drive/My Drive/ILSVRC2012_img_val/", transform=transform)
    test_loader = data.DataLoader(test_set, batch_size=100, shuffle=True, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
    model = torchvision.models.resnet18(pretrained=True).to(device)
    model.eval()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
    correct_top1 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
            
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# step : 1 / 500.0
# top-1 percentage :  66.00%
# step : 2 / 500.0
# top-1 percentage :  68.50%
# step : 3 / 500.0
# top-1 percentage :  70.33%
# step : 4 / 500.0
# top-1 percentage :  67.50%
# step : 5 / 500.0
# top-1 percentage :  66.00%
# step : 6 / 500.0
# top-1 percentage :  67.00%
# step : 7 / 500.0
# top-1 percentage :  66.86%
# step : 8 / 500.0
# top-1 percentage :  67.38%
# step : 9 / 500.0
# top-1 percentage :  68.11%
# step : 10 / 500.0
# top-1 percentage :  67.80%
# step : 11 / 500.0
# top-1 percentage :  67.18%
# step : 12 / 500.0
# top-1 percentage :  67.33%
# step : 13 / 500.0
# top-1 percentage :  67.23%
# step : 14 / 500.0
# top-1 percentage :  66.71%
# step : 15 / 500.0
# top-1 percentage :  67.47%
# step : 16 / 500.0
# top-1 percentage :  67.19%
# step : 17 / 500.0
# top-1 percentage :  67.65%
# step : 18 / 500.0
# top-1 percentage :  67.50%
# step : 19 / 500.0
# top-1 percentage :  67.11%
# step : 20 / 500.0
# top-1 percentage :  67.15%
# step : 21 / 500.0
# top-1 percentage :  67.43%
# step : 22 / 500.0
# top-1 percentage :  67.50%
# step : 23 / 500.0
# top-1 percentage :  67.48%
# step : 24 / 500.0
# top-1 percentage :  67.67%
# step : 25 / 500.0
# top-1 percentage :  67.88%
# step : 26 / 500.0
# top-1 percentage :  67.88%
# step : 27 / 500.0
# top-1 percentage :  67.56%
# step : 28 / 500.0
# top-1 percentage :  67.68%
# step : 29 / 500.0
# top-1 percentage :  67.48%
# step : 30 / 500.0
# top-1 percentage :  67.73%
# step : 31 / 500.0
# top-1 percentage :  67.68%
# step : 32 / 500.0
# top-1 percentage :  67.84%
# step : 33 / 500.0
# top-1 percentage :  67.91%
# step : 34 / 500.0
# top-1 percentage :  67.94%
# step : 35 / 500.0
# top-1 percentage :  68.00%
# step : 36 / 500.0
# top-1 percentage :  68.19%
# step : 37 / 500.0
# top-1 percentage :  67.95%
# step : 38 / 500.0
# top-1 percentage :  67.92%
# step : 39 / 500.0
# top-1 percentage :  67.97%
# step : 40 / 500.0
# top-1 percentage :  68.12%
# step : 41 / 500.0
# top-1 percentage :  68.27%
# step : 42 / 500.0
# top-1 percentage :  68.33%
# step : 43 / 500.0
# top-1 percentage :  68.26%
# step : 44 / 500.0
# top-1 percentage :  68.16%
# step : 45 / 500.0
# top-1 percentage :  68.02%
# step : 46 / 500.0
# top-1 percentage :  68.17%
# step : 47 / 500.0
# top-1 percentage :  68.38%
# step : 48 / 500.0
# top-1 percentage :  68.31%
# step : 49 / 500.0
# top-1 percentage :  68.18%
# step : 50 / 500.0
# top-1 percentage :  68.14%
# step : 51 / 500.0
# top-1 percentage :  68.08%
# step : 52 / 500.0
# top-1 percentage :  68.12%
# step : 53 / 500.0
# top-1 percentage :  68.21%
# step : 54 / 500.0
# top-1 percentage :  68.33%
# step : 55 / 500.0
# top-1 percentage :  68.58%
# step : 56 / 500.0
# top-1 percentage :  68.54%
# step : 57 / 500.0
# top-1 percentage :  68.63%
# step : 58 / 500.0
# top-1 percentage :  68.67%
# step : 59 / 500.0
# top-1 percentage :  68.58%
# step : 60 / 500.0
# top-1 percentage :  68.45%
# step : 61 / 500.0
# top-1 percentage :  68.51%
# step : 62 / 500.0
# top-1 percentage :  68.45%
# step : 63 / 500.0
# top-1 percentage :  68.51%
# step : 64 / 500.0
# top-1 percentage :  68.48%
# step : 65 / 500.0
# top-1 percentage :  68.58%
# step : 66 / 500.0
# top-1 percentage :  68.56%
# step : 67 / 500.0
# top-1 percentage :  68.55%
# step : 68 / 500.0
# top-1 percentage :  68.46%
# step : 69 / 500.0
# top-1 percentage :  68.51%
# step : 70 / 500.0
# top-1 percentage :  68.50%
# step : 71 / 500.0
# top-1 percentage :  68.54%
# step : 72 / 500.0
# top-1 percentage :  68.60%
# step : 73 / 500.0
# top-1 percentage :  68.59%
# step : 74 / 500.0
# top-1 percentage :  68.68%
# step : 75 / 500.0
# top-1 percentage :  68.73%
# step : 76 / 500.0
# top-1 percentage :  68.82%
# step : 77 / 500.0
# top-1 percentage :  68.68%
# step : 78 / 500.0
# top-1 percentage :  68.69%
# step : 79 / 500.0
# top-1 percentage :  68.66%
# step : 80 / 500.0
# top-1 percentage :  68.66%
# step : 81 / 500.0
# top-1 percentage :  68.65%
# step : 82 / 500.0
# top-1 percentage :  68.73%
# step : 83 / 500.0
# top-1 percentage :  68.76%
# step : 84 / 500.0
# top-1 percentage :  68.85%
# step : 85 / 500.0
# top-1 percentage :  68.86%
# step : 86 / 500.0
# top-1 percentage :  68.83%
# step : 87 / 500.0
# top-1 percentage :  68.85%
# step : 88 / 500.0
# top-1 percentage :  68.88%
# step : 89 / 500.0
# top-1 percentage :  68.83%
# step : 90 / 500.0
# top-1 percentage :  68.86%
# step : 91 / 500.0
# top-1 percentage :  68.91%
# step : 92 / 500.0
# top-1 percentage :  68.96%
# step : 93 / 500.0
# top-1 percentage :  68.94%
# step : 94 / 500.0
# top-1 percentage :  68.93%
# step : 95 / 500.0
# top-1 percentage :  68.96%
# step : 96 / 500.0
# top-1 percentage :  69.03%
# step : 97 / 500.0
# top-1 percentage :  69.04%
# step : 98 / 500.0
# top-1 percentage :  69.04%
# step : 99 / 500.0
# top-1 percentage :  69.06%
# step : 100 / 500.0
# top-1 percentage :  69.05%
# step : 101 / 500.0
# top-1 percentage :  68.97%
# step : 102 / 500.0
# top-1 percentage :  68.94%
# step : 103 / 500.0
# top-1 percentage :  69.01%
# step : 104 / 500.0
# top-1 percentage :  69.08%
# step : 105 / 500.0
# top-1 percentage :  69.07%
# step : 106 / 500.0
# top-1 percentage :  69.00%
# step : 107 / 500.0
# top-1 percentage :  69.06%
# step : 108 / 500.0
# top-1 percentage :  69.03%
# step : 109 / 500.0
# top-1 percentage :  69.03%
# step : 110 / 500.0
# top-1 percentage :  69.02%
# step : 111 / 500.0
# top-1 percentage :  69.08%
# step : 112 / 500.0
# top-1 percentage :  69.07%
# step : 113 / 500.0
# top-1 percentage :  68.99%
# step : 114 / 500.0
# top-1 percentage :  68.92%
# step : 115 / 500.0
# top-1 percentage :  68.90%
# step : 116 / 500.0
# top-1 percentage :  68.89%
# step : 117 / 500.0
# top-1 percentage :  68.91%
# step : 118 / 500.0
# top-1 percentage :  68.98%
# step : 119 / 500.0
# top-1 percentage :  68.99%
# step : 120 / 500.0
# top-1 percentage :  69.01%
# step : 121 / 500.0
# top-1 percentage :  69.03%
# step : 122 / 500.0
# top-1 percentage :  68.96%
# step : 123 / 500.0
# top-1 percentage :  68.97%
# step : 124 / 500.0
# top-1 percentage :  69.00%
# step : 125 / 500.0
# top-1 percentage :  69.01%
# step : 126 / 500.0
# top-1 percentage :  69.02%
# step : 127 / 500.0
# top-1 percentage :  69.06%
# step : 128 / 500.0
# top-1 percentage :  69.04%
# step : 129 / 500.0
# top-1 percentage :  69.00%
# step : 130 / 500.0
# top-1 percentage :  69.01%
# step : 131 / 500.0
# top-1 percentage :  69.05%
# step : 132 / 500.0
# top-1 percentage :  69.11%
# step : 133 / 500.0
# top-1 percentage :  69.17%
# step : 134 / 500.0
# top-1 percentage :  69.18%
# step : 135 / 500.0
# top-1 percentage :  69.22%
# step : 136 / 500.0
# top-1 percentage :  69.15%
# step : 137 / 500.0
# top-1 percentage :  69.21%
# step : 138 / 500.0
# top-1 percentage :  69.25%
# step : 139 / 500.0
# top-1 percentage :  69.18%
# step : 140 / 500.0
# top-1 percentage :  69.16%
# step : 141 / 500.0
# top-1 percentage :  69.13%
# step : 142 / 500.0
# top-1 percentage :  69.16%
# step : 143 / 500.0
# top-1 percentage :  69.23%
# step : 144 / 500.0
# top-1 percentage :  69.22%
# step : 145 / 500.0
# top-1 percentage :  69.21%
# step : 146 / 500.0
# top-1 percentage :  69.17%
# step : 147 / 500.0
# top-1 percentage :  69.18%
# step : 148 / 500.0
# top-1 percentage :  69.25%
# step : 149 / 500.0
# top-1 percentage :  69.28%
# step : 150 / 500.0
# top-1 percentage :  69.24%
# step : 151 / 500.0
# top-1 percentage :  69.24%
# step : 152 / 500.0
# top-1 percentage :  69.27%
# step : 153 / 500.0
# top-1 percentage :  69.21%
# step : 154 / 500.0
# top-1 percentage :  69.25%
# step : 155 / 500.0
# top-1 percentage :  69.26%
# step : 156 / 500.0
# top-1 percentage :  69.26%
# step : 157 / 500.0
# top-1 percentage :  69.20%
# step : 158 / 500.0
# top-1 percentage :  69.23%
# step : 159 / 500.0
# top-1 percentage :  69.21%
# step : 160 / 500.0
# top-1 percentage :  69.27%
# step : 161 / 500.0
# top-1 percentage :  69.25%
# step : 162 / 500.0
# top-1 percentage :  69.23%
# step : 163 / 500.0
# top-1 percentage :  69.26%
# step : 164 / 500.0
# top-1 percentage :  69.29%
# step : 165 / 500.0
# top-1 percentage :  69.24%
# step : 166 / 500.0
# top-1 percentage :  69.28%
# step : 167 / 500.0
# top-1 percentage :  69.38%
# step : 168 / 500.0
# top-1 percentage :  69.42%
# step : 169 / 500.0
# top-1 percentage :  69.43%
# step : 170 / 500.0
# top-1 percentage :  69.42%
# step : 171 / 500.0
# top-1 percentage :  69.37%
# step : 172 / 500.0
# top-1 percentage :  69.40%
# step : 173 / 500.0
# top-1 percentage :  69.43%
# step : 174 / 500.0
# top-1 percentage :  69.39%
# step : 175 / 500.0
# top-1 percentage :  69.37%
# step : 176 / 500.0
# top-1 percentage :  69.41%
# step : 177 / 500.0
# top-1 percentage :  69.39%
# step : 178 / 500.0
# top-1 percentage :  69.40%
# step : 179 / 500.0
# top-1 percentage :  69.40%
# step : 180 / 500.0
# top-1 percentage :  69.37%
# step : 181 / 500.0
# top-1 percentage :  69.39%
# step : 182 / 500.0
# top-1 percentage :  69.38%
# step : 183 / 500.0
# top-1 percentage :  69.44%
# step : 184 / 500.0
# top-1 percentage :  69.48%
# step : 185 / 500.0
# top-1 percentage :  69.46%
# step : 186 / 500.0
# top-1 percentage :  69.44%
# step : 187 / 500.0
# top-1 percentage :  69.41%
# step : 188 / 500.0
# top-1 percentage :  69.38%
# step : 189 / 500.0
# top-1 percentage :  69.36%
# step : 190 / 500.0
# top-1 percentage :  69.37%
# step : 191 / 500.0
# top-1 percentage :  69.41%
# step : 192 / 500.0
# top-1 percentage :  69.41%
# step : 193 / 500.0
# top-1 percentage :  69.42%
# step : 194 / 500.0
# top-1 percentage :  69.44%
# step : 195 / 500.0
# top-1 percentage :  69.44%
# step : 196 / 500.0
# top-1 percentage :  69.44%
# step : 197 / 500.0
# top-1 percentage :  69.41%
# step : 198 / 500.0
# top-1 percentage :  69.44%
# step : 199 / 500.0
# top-1 percentage :  69.42%
# step : 200 / 500.0
# top-1 percentage :  69.38%
# step : 201 / 500.0
# top-1 percentage :  69.36%
# step : 202 / 500.0
# top-1 percentage :  69.39%
# step : 203 / 500.0
# top-1 percentage :  69.35%
# step : 204 / 500.0
# top-1 percentage :  69.35%
# step : 205 / 500.0
# top-1 percentage :  69.33%
# step : 206 / 500.0
# top-1 percentage :  69.34%
# step : 207 / 500.0
# top-1 percentage :  69.37%
# step : 208 / 500.0
# top-1 percentage :  69.39%
# step : 209 / 500.0
# top-1 percentage :  69.34%
# step : 210 / 500.0
# top-1 percentage :  69.35%
# step : 211 / 500.0
# top-1 percentage :  69.34%
# step : 212 / 500.0
# top-1 percentage :  69.36%
# step : 213 / 500.0
# top-1 percentage :  69.41%
# step : 214 / 500.0
# top-1 percentage :  69.41%
# step : 215 / 500.0
# top-1 percentage :  69.37%
# step : 216 / 500.0
# top-1 percentage :  69.38%
# step : 217 / 500.0
# top-1 percentage :  69.38%
# step : 218 / 500.0
# top-1 percentage :  69.39%
# step : 219 / 500.0
# top-1 percentage :  69.37%
# step : 220 / 500.0
# top-1 percentage :  69.39%
# step : 221 / 500.0
# top-1 percentage :  69.43%
# step : 222 / 500.0
# top-1 percentage :  69.42%
# step : 223 / 500.0
# top-1 percentage :  69.42%
# step : 224 / 500.0
# top-1 percentage :  69.45%
# step : 225 / 500.0
# top-1 percentage :  69.42%
# step : 226 / 500.0
# top-1 percentage :  69.46%
# step : 227 / 500.0
# top-1 percentage :  69.41%
# step : 228 / 500.0
# top-1 percentage :  69.45%
# step : 229 / 500.0
# top-1 percentage :  69.41%
# step : 230 / 500.0
# top-1 percentage :  69.42%
# step : 231 / 500.0
# top-1 percentage :  69.40%
# step : 232 / 500.0
# top-1 percentage :  69.38%
# step : 233 / 500.0
# top-1 percentage :  69.32%
# step : 234 / 500.0
# top-1 percentage :  69.35%
# step : 235 / 500.0
# top-1 percentage :  69.38%
# step : 236 / 500.0
# top-1 percentage :  69.39%
# step : 237 / 500.0
# top-1 percentage :  69.41%
# step : 238 / 500.0
# top-1 percentage :  69.39%
# step : 239 / 500.0
# top-1 percentage :  69.38%
# step : 240 / 500.0
# top-1 percentage :  69.35%
# step : 241 / 500.0
# top-1 percentage :  69.37%
# step : 242 / 500.0
# top-1 percentage :  69.40%
# step : 243 / 500.0
# top-1 percentage :  69.40%
# step : 244 / 500.0
# top-1 percentage :  69.39%
# step : 245 / 500.0
# top-1 percentage :  69.40%
# step : 246 / 500.0
# top-1 percentage :  69.39%
# step : 247 / 500.0
# top-1 percentage :  69.39%
# step : 248 / 500.0
# top-1 percentage :  69.40%
# step : 249 / 500.0
# top-1 percentage :  69.41%
# step : 250 / 500.0
# top-1 percentage :  69.42%
# step : 251 / 500.0
# top-1 percentage :  69.45%
# step : 252 / 500.0
# top-1 percentage :  69.45%
# step : 253 / 500.0
# top-1 percentage :  69.44%
# step : 254 / 500.0
# top-1 percentage :  69.44%
# step : 255 / 500.0
# top-1 percentage :  69.41%
# step : 256 / 500.0
# top-1 percentage :  69.42%
# step : 257 / 500.0
# top-1 percentage :  69.42%
# step : 258 / 500.0
# top-1 percentage :  69.43%
# step : 259 / 500.0
# top-1 percentage :  69.42%
# step : 260 / 500.0
# top-1 percentage :  69.42%
# step : 261 / 500.0
# top-1 percentage :  69.43%
# step : 262 / 500.0
# top-1 percentage :  69.44%
# step : 263 / 500.0
# top-1 percentage :  69.46%
# step : 264 / 500.0
# top-1 percentage :  69.45%
# step : 265 / 500.0
# top-1 percentage :  69.45%
# step : 266 / 500.0
# top-1 percentage :  69.47%
# step : 267 / 500.0
# top-1 percentage :  69.47%
# step : 268 / 500.0
# top-1 percentage :  69.44%
# step : 269 / 500.0
# top-1 percentage :  69.48%
# step : 270 / 500.0
# top-1 percentage :  69.49%
# step : 271 / 500.0
# top-1 percentage :  69.49%
# step : 272 / 500.0
# top-1 percentage :  69.51%
# step : 273 / 500.0
# top-1 percentage :  69.52%
# step : 274 / 500.0
# top-1 percentage :  69.53%
# step : 275 / 500.0
# top-1 percentage :  69.53%
# step : 276 / 500.0
# top-1 percentage :  69.54%
# step : 277 / 500.0
# top-1 percentage :  69.52%
# step : 278 / 500.0
# top-1 percentage :  69.51%
# step : 279 / 500.0
# top-1 percentage :  69.51%
# step : 280 / 500.0
# top-1 percentage :  69.53%
# step : 281 / 500.0
# top-1 percentage :  69.52%
# step : 282 / 500.0
# top-1 percentage :  69.55%
# step : 283 / 500.0
# top-1 percentage :  69.57%
# step : 284 / 500.0
# top-1 percentage :  69.56%
# step : 285 / 500.0
# top-1 percentage :  69.56%
# step : 286 / 500.0
# top-1 percentage :  69.53%
# step : 287 / 500.0
# top-1 percentage :  69.54%
# step : 288 / 500.0
# top-1 percentage :  69.54%
# step : 289 / 500.0
# top-1 percentage :  69.55%
# step : 290 / 500.0
# top-1 percentage :  69.54%
# step : 291 / 500.0
# top-1 percentage :  69.53%
# step : 292 / 500.0
# top-1 percentage :  69.53%
# step : 293 / 500.0
# top-1 percentage :  69.52%
# step : 294 / 500.0
# top-1 percentage :  69.53%
# step : 295 / 500.0
# top-1 percentage :  69.53%
# step : 296 / 500.0
# top-1 percentage :  69.53%
# step : 297 / 500.0
# top-1 percentage :  69.52%
# step : 298 / 500.0
# top-1 percentage :  69.54%
# step : 299 / 500.0
# top-1 percentage :  69.54%
# step : 300 / 500.0
# top-1 percentage :  69.57%
# step : 301 / 500.0
# top-1 percentage :  69.58%
# step : 302 / 500.0
# top-1 percentage :  69.61%
# step : 303 / 500.0
# top-1 percentage :  69.60%
# step : 304 / 500.0
# top-1 percentage :  69.60%
# step : 305 / 500.0
# top-1 percentage :  69.60%
# step : 306 / 500.0
# top-1 percentage :  69.60%
# step : 307 / 500.0
# top-1 percentage :  69.60%
# step : 308 / 500.0
# top-1 percentage :  69.60%
# step : 309 / 500.0
# top-1 percentage :  69.62%
# step : 310 / 500.0
# top-1 percentage :  69.61%
# step : 311 / 500.0
# top-1 percentage :  69.62%
# step : 312 / 500.0
# top-1 percentage :  69.64%
# step : 313 / 500.0
# top-1 percentage :  69.64%
# step : 314 / 500.0
# top-1 percentage :  69.63%
# step : 315 / 500.0
# top-1 percentage :  69.64%
# step : 316 / 500.0
# top-1 percentage :  69.62%
# step : 317 / 500.0
# top-1 percentage :  69.61%
# step : 318 / 500.0
# top-1 percentage :  69.61%
# step : 319 / 500.0
# top-1 percentage :  69.61%
# step : 320 / 500.0
# top-1 percentage :  69.60%
# step : 321 / 500.0
# top-1 percentage :  69.59%
# step : 322 / 500.0
# top-1 percentage :  69.59%
# step : 323 / 500.0
# top-1 percentage :  69.60%
# step : 324 / 500.0
# top-1 percentage :  69.56%
# step : 325 / 500.0
# top-1 percentage :  69.57%
# step : 326 / 500.0
# top-1 percentage :  69.59%
# step : 327 / 500.0
# top-1 percentage :  69.58%
# step : 328 / 500.0
# top-1 percentage :  69.59%
# step : 329 / 500.0
# top-1 percentage :  69.60%
# step : 330 / 500.0
# top-1 percentage :  69.59%
# step : 331 / 500.0
# top-1 percentage :  69.59%
# step : 332 / 500.0
# top-1 percentage :  69.60%
# step : 333 / 500.0
# top-1 percentage :  69.61%
# step : 334 / 500.0
# top-1 percentage :  69.60%
# step : 335 / 500.0
# top-1 percentage :  69.60%
# step : 336 / 500.0
# top-1 percentage :  69.58%
# step : 337 / 500.0
# top-1 percentage :  69.58%
# step : 338 / 500.0
# top-1 percentage :  69.58%
# step : 339 / 500.0
# top-1 percentage :  69.59%
# step : 340 / 500.0
# top-1 percentage :  69.60%
# step : 341 / 500.0
# top-1 percentage :  69.60%
# step : 342 / 500.0
# top-1 percentage :  69.59%
# step : 343 / 500.0
# top-1 percentage :  69.58%
# step : 344 / 500.0
# top-1 percentage :  69.60%
# step : 345 / 500.0
# top-1 percentage :  69.60%
# step : 346 / 500.0
# top-1 percentage :  69.58%
# step : 347 / 500.0
# top-1 percentage :  69.60%
# step : 348 / 500.0
# top-1 percentage :  69.60%
# step : 349 / 500.0
# top-1 percentage :  69.60%
# step : 350 / 500.0
# top-1 percentage :  69.62%
# step : 351 / 500.0
# top-1 percentage :  69.61%
# step : 352 / 500.0
# top-1 percentage :  69.62%
# step : 353 / 500.0
# top-1 percentage :  69.61%
# step : 354 / 500.0
# top-1 percentage :  69.61%
# step : 355 / 500.0
# top-1 percentage :  69.61%
# step : 356 / 500.0
# top-1 percentage :  69.60%
# step : 357 / 500.0
# top-1 percentage :  69.60%
# step : 358 / 500.0
# top-1 percentage :  69.59%
# step : 359 / 500.0
# top-1 percentage :  69.59%
# step : 360 / 500.0
# top-1 percentage :  69.58%
# step : 361 / 500.0
# top-1 percentage :  69.58%
# step : 362 / 500.0
# top-1 percentage :  69.57%
# step : 363 / 500.0
# top-1 percentage :  69.56%
# step : 364 / 500.0
# top-1 percentage :  69.57%
# step : 365 / 500.0
# top-1 percentage :  69.57%
# step : 366 / 500.0
# top-1 percentage :  69.58%
# step : 367 / 500.0
# top-1 percentage :  69.60%
# step : 368 / 500.0
# top-1 percentage :  69.60%
# step : 369 / 500.0
# top-1 percentage :  69.61%
# step : 370 / 500.0
# top-1 percentage :  69.61%
# step : 371 / 500.0
# top-1 percentage :  69.62%
# step : 372 / 500.0
# top-1 percentage :  69.63%
# step : 373 / 500.0
# top-1 percentage :  69.64%
# step : 374 / 500.0
# top-1 percentage :  69.64%
# step : 375 / 500.0
# top-1 percentage :  69.65%
# step : 376 / 500.0
# top-1 percentage :  69.65%
# step : 377 / 500.0
# top-1 percentage :  69.64%
# step : 378 / 500.0
# top-1 percentage :  69.64%
# step : 379 / 500.0
# top-1 percentage :  69.63%
# step : 380 / 500.0
# top-1 percentage :  69.66%
# step : 381 / 500.0
# top-1 percentage :  69.66%
# step : 382 / 500.0
# top-1 percentage :  69.65%
# step : 383 / 500.0
# top-1 percentage :  69.65%
# step : 384 / 500.0
# top-1 percentage :  69.63%
# step : 385 / 500.0
# top-1 percentage :  69.63%
# step : 386 / 500.0
# top-1 percentage :  69.64%
# step : 387 / 500.0
# top-1 percentage :  69.67%
# step : 388 / 500.0
# top-1 percentage :  69.65%
# step : 389 / 500.0
# top-1 percentage :  69.65%
# step : 390 / 500.0
# top-1 percentage :  69.66%
# step : 391 / 500.0
# top-1 percentage :  69.65%
# step : 392 / 500.0
# top-1 percentage :  69.68%
# step : 393 / 500.0
# top-1 percentage :  69.69%
# step : 394 / 500.0
# top-1 percentage :  69.70%
# step : 395 / 500.0
# top-1 percentage :  69.70%
# step : 396 / 500.0
# top-1 percentage :  69.69%
# step : 397 / 500.0
# top-1 percentage :  69.68%
# step : 398 / 500.0
# top-1 percentage :  69.67%
# step : 399 / 500.0
# top-1 percentage :  69.67%
# step : 400 / 500.0
# top-1 percentage :  69.67%
# step : 401 / 500.0
# top-1 percentage :  69.67%
# step : 402 / 500.0
# top-1 percentage :  69.70%
# step : 403 / 500.0
# top-1 percentage :  69.70%
# step : 404 / 500.0
# top-1 percentage :  69.71%
# step : 405 / 500.0
# top-1 percentage :  69.71%
# step : 406 / 500.0
# top-1 percentage :  69.71%
# step : 407 / 500.0
# top-1 percentage :  69.72%
# step : 408 / 500.0
# top-1 percentage :  69.73%
# step : 409 / 500.0
# top-1 percentage :  69.74%
# step : 410 / 500.0
# top-1 percentage :  69.74%
# step : 411 / 500.0
# top-1 percentage :  69.76%
# step : 412 / 500.0
# top-1 percentage :  69.74%
# step : 413 / 500.0
# top-1 percentage :  69.73%
# step : 414 / 500.0
# top-1 percentage :  69.75%
# step : 415 / 500.0
# top-1 percentage :  69.75%
# step : 416 / 500.0
# top-1 percentage :  69.75%
# step : 417 / 500.0
# top-1 percentage :  69.74%
# step : 418 / 500.0
# top-1 percentage :  69.74%
# step : 419 / 500.0
# top-1 percentage :  69.73%
# step : 420 / 500.0
# top-1 percentage :  69.75%
# step : 421 / 500.0
# top-1 percentage :  69.74%
# step : 422 / 500.0
# top-1 percentage :  69.75%
# step : 423 / 500.0
# top-1 percentage :  69.76%
# step : 424 / 500.0
# top-1 percentage :  69.77%
# step : 425 / 500.0
# top-1 percentage :  69.77%
# step : 426 / 500.0
# top-1 percentage :  69.77%
# step : 427 / 500.0
# top-1 percentage :  69.76%
# step : 428 / 500.0
# top-1 percentage :  69.76%
# step : 429 / 500.0
# top-1 percentage :  69.76%
# step : 430 / 500.0
# top-1 percentage :  69.76%
# step : 431 / 500.0
# top-1 percentage :  69.76%
# step : 432 / 500.0
# top-1 percentage :  69.76%
# step : 433 / 500.0
# top-1 percentage :  69.77%
# step : 434 / 500.0
# top-1 percentage :  69.76%
# step : 435 / 500.0
# top-1 percentage :  69.79%
# step : 436 / 500.0
# top-1 percentage :  69.79%
# step : 437 / 500.0
# top-1 percentage :  69.78%
# step : 438 / 500.0
# top-1 percentage :  69.78%
# step : 439 / 500.0
# top-1 percentage :  69.77%
# step : 440 / 500.0
# top-1 percentage :  69.75%
# step : 441 / 500.0
# top-1 percentage :  69.75%
# step : 442 / 500.0
# top-1 percentage :  69.74%
# step : 443 / 500.0
# top-1 percentage :  69.74%
# step : 444 / 500.0
# top-1 percentage :  69.74%
# step : 445 / 500.0
# top-1 percentage :  69.74%
# step : 446 / 500.0
# top-1 percentage :  69.73%
# step : 447 / 500.0
# top-1 percentage :  69.73%
# step : 448 / 500.0
# top-1 percentage :  69.75%
# step : 449 / 500.0
# top-1 percentage :  69.75%
# step : 450 / 500.0
# top-1 percentage :  69.74%
# step : 451 / 500.0
# top-1 percentage :  69.75%
# step : 452 / 500.0
# top-1 percentage :  69.74%
# step : 453 / 500.0
# top-1 percentage :  69.74%
# step : 454 / 500.0
# top-1 percentage :  69.76%
# step : 455 / 500.0
# top-1 percentage :  69.75%
# step : 456 / 500.0
# top-1 percentage :  69.75%
# step : 457 / 500.0
# top-1 percentage :  69.74%
# step : 458 / 500.0
# top-1 percentage :  69.73%
# step : 459 / 500.0
# top-1 percentage :  69.72%
# step : 460 / 500.0
# top-1 percentage :  69.72%
# step : 461 / 500.0
# top-1 percentage :  69.71%
# step : 462 / 500.0
# top-1 percentage :  69.72%
# step : 463 / 500.0
# top-1 percentage :  69.72%
# step : 464 / 500.0
# top-1 percentage :  69.72%
# step : 465 / 500.0
# top-1 percentage :  69.73%
# step : 466 / 500.0
# top-1 percentage :  69.73%
# step : 467 / 500.0
# top-1 percentage :  69.73%
# step : 468 / 500.0
# top-1 percentage :  69.73%
# step : 469 / 500.0
# top-1 percentage :  69.73%
# step : 470 / 500.0
# top-1 percentage :  69.74%
# step : 471 / 500.0
# top-1 percentage :  69.75%
# step : 472 / 500.0
# top-1 percentage :  69.75%
# step : 473 / 500.0
# top-1 percentage :  69.75%
# step : 474 / 500.0
# top-1 percentage :  69.75%
# step : 475 / 500.0
# top-1 percentage :  69.76%
# step : 476 / 500.0
# top-1 percentage :  69.76%
# step : 477 / 500.0
# top-1 percentage :  69.76%
# step : 478 / 500.0
# top-1 percentage :  69.75%
# step : 479 / 500.0
# top-1 percentage :  69.76%
# step : 480 / 500.0
# top-1 percentage :  69.77%
# step : 481 / 500.0
# top-1 percentage :  69.77%
# step : 482 / 500.0
# top-1 percentage :  69.75%
# step : 483 / 500.0
# top-1 percentage :  69.74%
# step : 484 / 500.0
# top-1 percentage :  69.73%
# step : 485 / 500.0
# top-1 percentage :  69.72%
# step : 486 / 500.0
# top-1 percentage :  69.72%
# step : 487 / 500.0
# top-1 percentage :  69.74%
# step : 488 / 500.0
# top-1 percentage :  69.74%
# step : 489 / 500.0
# top-1 percentage :  69.75%
# step : 490 / 500.0
# top-1 percentage :  69.74%
# step : 491 / 500.0
# top-1 percentage :  69.74%
# step : 492 / 500.0
# top-1 percentage :  69.74%
# step : 493 / 500.0
# top-1 percentage :  69.73%
# step : 494 / 500.0
# top-1 percentage :  69.73%
# step : 495 / 500.0
# top-1 percentage :  69.73%
# step : 496 / 500.0
# top-1 percentage :  69.74%
# step : 497 / 500.0
# top-1 percentage :  69.75%
# step : 498 / 500.0
# top-1 percentage :  69.76%
# step : 499 / 500.0
# top-1 percentage :  69.76%
# step : 500 / 500.0
# top-1 percentage :  69.76%
# top-1 percentage :  69.76%
